# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
adata = sc.read_h5ad("/home/luosg/Data/genomeStability/output/luancao/scRNAseq/common/5_combine_h5ad/ovaries/ovaries_cellranger_clustered_v3.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 17395 × 3000
#     obs: 'sample_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'doublet_score', 'predicted_doublet', 'leiden'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'hb', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'mean', 'std'
#     uns: 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
#     layers: 'counts', None (.X)

# %%
adata.layers['counts'].min(), adata.layers['counts'].max(), adata.layers['counts'].mean()
# Out:
# (np.float32(0.0), np.float32(8212.0), np.float32(0.65557903))
