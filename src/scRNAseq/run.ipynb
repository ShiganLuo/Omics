# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
h5ad_merge = "/home/luosg/Data/genomeStability/output/luancao/scRNAseq/common/5_combine_h5ad/ovaries/ovaries_cellranger_merged.h5ad"
h5ad_cluster = "/home/luosg/Data/genomeStability/output/luancao/scRNAseq/common/5_combine_h5ad/ovaries/ovaries_cellranger_clustered.h5ad"
ad_merge = sc.read_h5ad(h5ad_merge)
ad_cluster = sc.read_h5ad(h5ad_cluster)
print(ad_merge)
print(ad_cluster)
# Out:
# /tmp/ipykernel_3437469/2047497800.py:3: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   ad_merge = sc.read_h5ad(h5ad_merge)
# AnnData object with n_obs × n_vars = 62474 × 26509
#     obs: 'sample_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'doublet_score', 'predicted_doublet'
#     layers: 'counts', None (.X)
# AnnData object with n_obs × n_vars = 62474 × 26509
# ...

# %%
sc.pl.umap(ad_cluster, color="leiden")

# %%
ad_merge
