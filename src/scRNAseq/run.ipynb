# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
adata = sc.read_h5ad("/home/luosg/Data/genomeStability/output/luancao/scRNAseq/common/5_combine_h5ad/ovaries/ovaries_scTE_v3_annotated.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 14943 × 3000
#     obs: 'sample_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'doublet_score', 'predicted_doublet', 'leiden', 'cell_type', 'score_Oocyte', 'score_Granulosa', 'score_Cumulus', 'score_Myofibroblast', 'score_Mesothelial', 'score_Theca', 'score_Luteal', 'score_Stromal', 'score_Endothelial', 'score_Lymphatic_endo', 'score_Smooth_muscle', 'score_Epithelial', 'score_Pericyte', 'score_Macrophage', 'score_T_cell', 'score_NK_cell', 'score_B_cell', 'score_Monocyte', 'score_Proliferating', 'score_ERVK_high', 'score_Alu_high'
#     var: 'mt', 'ribo', 'hb', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'mean', 'std'
#     uns: 'cell_type_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
#     layers: 'counts', None (.X)

# %%
sc.pl.umap(adata, color=['cell_type'],legend_loc='on data')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sc.pl.umap(adata, color=['cell_type'],on_data=True)
#
# File ~/Data/genomeStability/.venv/lib/python3.13/site-packages/scanpy/plotting/_tools/scatterplots.py:728, in umap(adata, **kwargs)
#     669 @_wraps_plot_scatter
#     670 @_doc_params(
#     671     adata_color_etc=doc_adata_color_etc,
#    (...)    675 )
#     676 def umap(adata: AnnData, **kwargs) -> Figure | Axes | list[Axes] | None:
#     677     """Scatter plot in UMAP basis.
#     678
#     679     Parameters
#    (...)    726
#     727     """
# --> 728     return embedding(adata, "umap", **kwargs)
#
# File ~/Data/genomeStability/.venv/lib/python3.13/site-packages/scanpy/plotting/_tools/scatterplots.py:421, in embedding(adata, basis, color, mask_obs, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, dimensions, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, colorbar_loc, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, ax, return_fig, marker, save, **kwargs)
#     419     if not MarkerStyle(marker[count]).is_filled():
#     420         edgecolor = None
# --> 421     cax = scatter(
#     422         coords[:, 0],
#     423         coords[:, 1],
#     424         c=color_vector,
#     425         rasterized=settings._vector_friendly,
#     426         marker=marker[count],
#     427         edgecolor=edgecolor,
#     428         **kwargs_scatter,
#     429     )
#     431 # remove y and x ticks
#     432 ax.set_yticks([])
#
# File ~/Data/genomeStability/.venv/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Data/genomeStability/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/Data/genomeStability/.venv/lib/python3.13/site-packages/matplotlib/axes/_axes.py:5055, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    5051         keys_str = ", ".join(f"'{k}'" for k in extra_keys)
#    5052         _api.warn_external(
#    5053             "No data for colormapping provided via 'c'. "
#    5054             f"Parameters {keys_str} will be ignored")
# -> 5055 collection._internal_update(kwargs)
#    5057 # Classic mode only:
#    5058 # ensure there are margins to allow for the
#    5059 # finite size of the symbols.  In v2.x, margins
#    5060 # are present by default, so we disable this
#    5061 # scatter-specific override.
#    5062 if mpl.rcParams['_internal.classic_mode']:
#
# File ~/Data/genomeStability/.venv/lib/python3.13/site-packages/matplotlib/artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File ~/Data/genomeStability/.venv/lib/python3.13/site-packages/matplotlib/artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: PathCollection.set() got an unexpected keyword argument 'on_data'
